# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name" : ["Abhinav", "Rahul", "Shivansh", "Display"],
    "marks" : [93, 4, 66, 33],
    "city" : ["Mumbai", "kalyan", "Madhubani", "Kolkata"]
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#        name  marks       city
# 0   Abhinav     93     Mumbai
# 1     Rahul      4     kalyan
# 2  Shivansh     66  Madhubani
# 3   Display     33    Kolkata

# %%
df.to_csv("friends.csv")

# %%
df.to_csv("friends_indexFalse.csv", index=False)

# %%
df.head(2)
# Out:
#       name  marks    city
# 0  Abhinav     93  Mumbai
# 1    Rahul      4  kalyan

# %%
df.tail(2)
# Out:
#        name  marks       city
# 2  Shivansh     66  Madhubani
# 3   Display     33    Kolkata

# %%
df.tail(10)
# Out:
#        name  marks       city
# 0   Abhinav     93     Mumbai
# 1     Rahul      4     kalyan
# 2  Shivansh     66  Madhubani
# 3   Display     33    Kolkata

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   49.000000
# std    38.755645
# min     4.000000
# 25%    25.750000
# 50%    49.500000
# 75%    72.750000
# max    93.000000

# %%
train = pd.read_csv("train.csv")

# %%
train["Speed"]
# Out:
# 0    129
# 1    123
# 2    200
# 3     90
# Name: Speed, dtype: int64

# %%
train["city"][0]
# Out:
# 'Mumbai'

# %%
train['city'][3] = "Patna"
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_2588/3634185913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['city'][3] = "Patna"

# %%
train.to_csv("train.csv", index=False)

# %%
train
# Out:
#    Tain no.  Speed    city
# 0    893009    129  Mumbai
# 1    239843    123   Delhi
# 2    234323    200    Kota
# 3    324234     90   Patna

# %%
train.index = ["First", "Second", "Third", "Fourth"]

# %%
train
# Out:
#         Tain no.  Speed    city
# First     893009    129  Mumbai
# Second    239843    123   Delhi
# Third     234323    200    Kota
# Fourth    324234     90   Patna

# %%
series = pd.Series(np.random.rand(20))

# %%
print(series, type(series))
# Out:
# 0     0.892308
# 1     0.019686
# 2     0.352222
# 3     0.680118
# 4     0.000105
# 5     0.523514
# 6     0.238157
# 7     0.755110
# 8     0.054363
# 9     0.329335
# 10    0.638200
# 11    0.372056
# 12    0.382897
# 13    0.484260
# 14    0.071149
# 15    0.614620
# 16    0.338400
# 17    0.352876
# 18    0.596942
# 19    0.891539
# dtype: float64 <class 'pandas.core.series.Series'>

# %%
new_df = pd.DataFrame(np.random.rand(445, 6), index=np.arange(445))

# %%
new_df.head()
# Out:
#           0         1         2         3         4         5
# 0  0.026610  0.389168  0.052477  0.423259  0.407235  0.100711
# 1  0.060224  0.987430  0.005725  0.153605  0.256132  0.982076
# 2  0.728610  0.238399  0.018725  0.408156  0.815878  0.495681
# 3  0.917867  0.467754  0.046411  0.870903  0.554316  0.693104
# 4  0.674388  0.011974  0.557985  0.551180  0.759762  0.372287

# %%
new_df.tail()
# Out:
#             0         1         2         3         4         5
# 440  0.366501  0.338691  0.065218  0.622642  0.255830  0.430014
# 441  0.612678  0.704572  0.355077  0.002490  0.082120  0.979282
# 442  0.534451  0.404527  0.873619  0.575251  0.915457  0.343716
# 443  0.209470  0.406620  0.171258  0.115146  0.074322  0.946204
# 444  0.319014  0.319168  0.302161  0.534227  0.648596  0.333659

# %%
new_df.describe()
# Out:
#                 0           1           2           3           4           5
# count  445.000000  445.000000  445.000000  445.000000  445.000000  445.000000
# mean     0.516150    0.510808    0.487933    0.493223    0.501742    0.514778
# std      0.289899    0.289509    0.299314    0.288052    0.303023    0.286151
# min      0.000958    0.002625    0.001943    0.000172    0.000170    0.003700
# 25%      0.283968    0.268569    0.223445    0.236386    0.233813    0.272133
# 50%      0.533974    0.517471    0.483275    0.493839    0.512254    0.516661
# 75%      0.749628    0.763479    0.745628    0.750959    0.770636    0.768644
# max      0.997996    0.997384    0.999605    0.986454    0.998772    0.999719

# %%
print(type(new_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
new_df[0][0] = "Abhinav"

# %%
new_df.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# dtype: object

# %%
new_df.head()
# Out:
#           0         1         2         3         4         5
# 0   Abhinav  0.389168  0.052477  0.423259  0.407235  0.100711
# 1  0.060224  0.987430  0.005725  0.153605  0.256132  0.982076
# 2   0.72861  0.238399  0.018725  0.408156  0.815878  0.495681
# 3  0.917867  0.467754  0.046411  0.870903  0.554316  0.693104
# 4  0.674388  0.011974  0.557985  0.551180  0.759762  0.372287

# %%
new_df[0][0] = 0.5

# %%
new_df.head()
# Out:
#           0         1         2         3         4         5
# 0       0.5  0.389168  0.052477  0.423259  0.407235  0.100711
# 1  0.060224  0.987430  0.005725  0.153605  0.256132  0.982076
# 2   0.72861  0.238399  0.018725  0.408156  0.815878  0.495681
# 3  0.917867  0.467754  0.046411  0.870903  0.554316  0.693104
# 4  0.674388  0.011974  0.557985  0.551180  0.759762  0.372287

# %%
new_df.T
# Out:
#         0         1         2         3         4         5         6    \
# 0       0.5  0.060224   0.72861  0.917867  0.674388  0.784892  0.886783
# 1  0.389168   0.98743  0.238399  0.467754  0.011974  0.760276   0.76625
# 2  0.052477  0.005725  0.018725  0.046411  0.557985  0.525272  0.807104
# 3  0.423259  0.153605  0.408156  0.870903   0.55118  0.418736  0.283976
# 4  0.407235  0.256132  0.815878  0.554316  0.759762   0.83523  0.080189
# 5  0.100711  0.982076  0.495681  0.693104  0.372287  0.500335  0.214146
#
#         7         8         9    ...       435       436       437       438  \
# 0  0.860829  0.377174  0.530079  ...  0.343045  0.569653  0.201789  0.807617
# 1  0.302666   0.50803  0.921069  ...  0.758312  0.691493  0.508827  0.081209
# 2  0.813198  0.557904  0.195634  ...  0.246998  0.040934  0.292267   0.13969
# 3  0.831537  0.856847  0.977804  ...  0.235377  0.513995  0.613691  0.825553
# 4  0.191315  0.194405  0.616893  ...  0.775289  0.662748  0.065268  0.094354
# ...

# %%
new_df.head()
# Out:
#           0         1         2         3         4         5
# 0       0.5  0.389168  0.052477  0.423259  0.407235  0.100711
# 1  0.060224  0.987430  0.005725  0.153605  0.256132  0.982076
# 2   0.72861  0.238399  0.018725  0.408156  0.815878  0.495681
# 3  0.917867  0.467754  0.046411  0.870903  0.554316  0.693104
# 4  0.674388  0.011974  0.557985  0.551180  0.759762  0.372287

# %%
new_df.sort_index(axis=0, ascending=False)
# Out:
#             0         1         2         3         4         5
# 444  0.319014  0.319168  0.302161  0.534227  0.648596  0.333659
# 443   0.20947  0.406620  0.171258  0.115146  0.074322  0.946204
# 442  0.534451  0.404527  0.873619  0.575251  0.915457  0.343716
# 441  0.612678  0.704572  0.355077  0.002490  0.082120  0.979282
# 440  0.366501  0.338691  0.065218  0.622642  0.255830  0.430014
# ..        ...       ...       ...       ...       ...       ...
# 4    0.674388  0.011974  0.557985  0.551180  0.759762  0.372287
# 3    0.917867  0.467754  0.046411  0.870903  0.554316  0.693104
# 2     0.72861  0.238399  0.018725  0.408156  0.815878  0.495681
# 1    0.060224  0.987430  0.005725  0.153605  0.256132  0.982076
# 0         0.5  0.389168  0.052477  0.423259  0.407235  0.100711
#
# [445 rows x 6 columns]

# %%
new_df.sort_index(axis=1, ascending=True)
# Out:
#             0         1         2         3         4         5
# 0         0.5  0.389168  0.052477  0.423259  0.407235  0.100711
# 1    0.060224  0.987430  0.005725  0.153605  0.256132  0.982076
# 2     0.72861  0.238399  0.018725  0.408156  0.815878  0.495681
# 3    0.917867  0.467754  0.046411  0.870903  0.554316  0.693104
# 4    0.674388  0.011974  0.557985  0.551180  0.759762  0.372287
# ..        ...       ...       ...       ...       ...       ...
# 440  0.366501  0.338691  0.065218  0.622642  0.255830  0.430014
# 441  0.612678  0.704572  0.355077  0.002490  0.082120  0.979282
# 442  0.534451  0.404527  0.873619  0.575251  0.915457  0.343716
# 443   0.20947  0.406620  0.171258  0.115146  0.074322  0.946204
# 444  0.319014  0.319168  0.302161  0.534227  0.648596  0.333659
#
# [445 rows x 6 columns]

# %%
type(new_df[0])
# Out:
# pandas.core.series.Series

# %%
new_df2 = new_df.copy()

# %%
new_df2[0][0] = 983
new_df2.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp/ipykernel_2588/250112503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df2[0][0] = 983
#           0         1         2         3         4         5
# 0       983  0.389168  0.052477  0.423259  0.407235  0.100711
# 1  0.060224  0.987430  0.005725  0.153605  0.256132  0.982076
# 2   0.72861  0.238399  0.018725  0.408156  0.815878  0.495681
# 3  0.917867  0.467754  0.046411  0.870903  0.554316  0.693104
# 4  0.674388  0.011974  0.557985  0.551180  0.759762  0.372287

# %%
new_df.head()
# Out:
#           0         1         2         3         4         5
# 0       0.5  0.389168  0.052477  0.423259  0.407235  0.100711
# 1  0.060224  0.987430  0.005725  0.153605  0.256132  0.982076
# 2   0.72861  0.238399  0.018725  0.408156  0.815878  0.495681
# 3  0.917867  0.467754  0.046411  0.870903  0.554316  0.693104
# 4  0.674388  0.011974  0.557985  0.551180  0.759762  0.372287

# %%
#new_df.loc[0, "A"] = 556  #no warning

# %%
new_df.head(2)
# Out:
#           0         1         2         3         4         5
# 0       0.5  0.389168  0.052477  0.423259  0.407235  0.100711
# 1  0.060224  0.987430  0.005725  0.153605  0.256132  0.982076

# %%
new_df.columns = list("ABCDEF")

# %%
new_df
# Out:
#             A         B         C         D         E         F
# 0         0.5  0.389168  0.052477  0.423259  0.407235  0.100711
# 1    0.060224  0.987430  0.005725  0.153605  0.256132  0.982076
# 2     0.72861  0.238399  0.018725  0.408156  0.815878  0.495681
# 3    0.917867  0.467754  0.046411  0.870903  0.554316  0.693104
# 4    0.674388  0.011974  0.557985  0.551180  0.759762  0.372287
# ..        ...       ...       ...       ...       ...       ...
# 440  0.366501  0.338691  0.065218  0.622642  0.255830  0.430014
# 441  0.612678  0.704572  0.355077  0.002490  0.082120  0.979282
# 442  0.534451  0.404527  0.873619  0.575251  0.915457  0.343716
# 443   0.20947  0.406620  0.171258  0.115146  0.074322  0.946204
# 444  0.319014  0.319168  0.302161  0.534227  0.648596  0.333659
#
# [445 rows x 6 columns]

# %%
new_df = new_df.drop("F", axis=1)

# %%
new_df.head()
# Out:
#           A         B         C         D         E
# 0       0.5  0.389168  0.052477  0.423259  0.407235
# 1  0.060224  0.987430  0.005725  0.153605  0.256132
# 2   0.72861  0.238399  0.018725  0.408156  0.815878
# 3  0.917867  0.467754  0.046411  0.870903  0.554316
# 4  0.674388  0.011974  0.557985  0.551180  0.759762

# %%
new_df.loc[[1, 2], ["C", "D"]]
new_df.loc[[1, 2], :]
new_df.loc[:, ["C", "D"]]
# Out:
#             C         D
# 0    0.052477  0.423259
# 1    0.005725  0.153605
# 2    0.018725  0.408156
# 3    0.046411  0.870903
# 4    0.557985  0.551180
# ..        ...       ...
# 440  0.065218  0.622642
# 441  0.355077  0.002490
# 442  0.873619  0.575251
# 443  0.171258  0.115146
# 444  0.302161  0.534227
#
# [445 rows x 2 columns]

# %% [markdown]
# # Try to Run Complex quearies in data frames

# %%
new_df.loc[new_df["A"] < 0.2]
new_df.loc[(new_df["B"] < 0.3) & (new_df["C"] > 0.1)]
# Out:
#             A         B         C         D         E
# 4    0.674388  0.011974  0.557985  0.551180  0.759762
# 10   0.829179  0.211144  0.371134  0.136553  0.272977
# 17   0.925586  0.051327  0.535076  0.874254  0.283409
# 18   0.512641  0.158534  0.718549  0.601395  0.048219
# 21   0.152236  0.011013  0.784818  0.930742  0.720872
# ..        ...       ...       ...       ...       ...
# 426  0.896218  0.086936  0.240439  0.680047  0.829503
# 427  0.578108  0.222270  0.603350  0.315899  0.892764
# 434  0.265823  0.033898  0.561601  0.238356  0.387588
# 438  0.807617  0.081209  0.139690  0.825553  0.094354
# 439  0.985746  0.102980  0.671839  0.336475  0.362165
#
# [110 rows x 5 columns]

# %%
new_df.loc[new_df["E"] > 0.9]
# Out:
#             A         B         C         D         E
# 20   0.700476  0.318166  0.446265  0.452350  0.975092
# 30   0.719321  0.095917  0.765699  0.952136  0.993519
# 46   0.338524  0.801239  0.332531  0.794931  0.944393
# 52   0.973236  0.688268  0.334913  0.308388  0.927064
# 60   0.641077  0.251376  0.045865  0.182716  0.998772
# 63    0.02972  0.097347  0.232487  0.092735  0.941263
# 66   0.381967  0.695714  0.660821  0.556530  0.945002
# 77   0.752311  0.326332  0.229070  0.454116  0.909116
# 85   0.045136  0.783774  0.500343  0.198155  0.928612
# 98   0.136255  0.952874  0.170436  0.869608  0.997110
# 124  0.778473  0.769224  0.796284  0.777322  0.901575
# 125  0.573409  0.539210  0.177848  0.780600  0.970819
# 132  0.379748  0.928989  0.586604  0.940622  0.957858
# 144  0.332267  0.435888  0.126135  0.792925  0.982656
# 152  0.595199  0.996046  0.696542  0.705715  0.925800
# 169  0.031856  0.125573  0.814471  0.160859  0.976219
# ...

# %%
new_df.loc[:]
# Out:
#             A         B         C         D         E
# 0         0.5  0.389168  0.052477  0.423259  0.407235
# 1    0.060224  0.987430  0.005725  0.153605  0.256132
# 2     0.72861  0.238399  0.018725  0.408156  0.815878
# 3    0.917867  0.467754  0.046411  0.870903  0.554316
# 4    0.674388  0.011974  0.557985  0.551180  0.759762
# ..        ...       ...       ...       ...       ...
# 440  0.366501  0.338691  0.065218  0.622642  0.255830
# 441  0.612678  0.704572  0.355077  0.002490  0.082120
# 442  0.534451  0.404527  0.873619  0.575251  0.915457
# 443   0.20947  0.406620  0.171258  0.115146  0.074322
# 444  0.319014  0.319168  0.302161  0.534227  0.648596
#
# [445 rows x 5 columns]

# %%
new_df.loc[10, "A"] = 108
new_df.dtypes
# Out:
# A     object
# B    float64
# C    float64
# D    float64
# E    float64
# dtype: object

# %%
new_df.head(3)
# Out:
#           A         B         C         D         E
# 0       0.5  0.389168  0.052477  0.423259  0.407235
# 1  0.060224  0.987430  0.005725  0.153605  0.256132
# 2   0.72861  0.238399  0.018725  0.408156  0.815878

# %%
print(new_df.iloc[0, 2])   # work with just index no need of ccolumns and rows name
print(new_df.iloc[:, 2])
# Out:
# 0.05247733093235396
# 0      0.052477
# 1      0.005725
# 2      0.018725
# 3      0.046411
# 4      0.557985
#          ...
# 440    0.065218
# 441    0.355077
# 442    0.873619
# 443    0.171258
# 444    0.302161
# Name: C, Length: 445, dtype: float64

# %%
new_df.iloc[[0, 3], [1, 4, 3]]
# Out:
#           B         E         D
# 0  0.389168  0.407235  0.423259
# 3  0.467754  0.554316  0.870903

# %%
new_df.iloc[0, 3] = 6
new_df.iloc[0, 3]
# Out:
# 6.0

# %%
new_df.drop({"A", "C"}, axis=1)
# Out:
#             B         D         E
# 0    0.389168  6.000000  0.407235
# 1    0.987430  0.153605  0.256132
# 2    0.238399  0.408156  0.815878
# 3    0.467754  0.870903  0.554316
# 4    0.011974  0.551180  0.759762
# ..        ...       ...       ...
# 440  0.338691  0.622642  0.255830
# 441  0.704572  0.002490  0.082120
# 442  0.404527  0.575251  0.915457
# 443  0.406620  0.115146  0.074322
# 444  0.319168  0.534227  0.648596
#
# [445 rows x 3 columns]

# %%
new_df.drop({4, 440, 444}, axis=0, inplace=True)

# %%
new_df
# Out:
#             A         B         C         D         E
# 0         0.5  0.389168  0.052477  6.000000  0.407235
# 1    0.060224  0.987430  0.005725  0.153605  0.256132
# 2     0.72861  0.238399  0.018725  0.408156  0.815878
# 3    0.917867  0.467754  0.046411  0.870903  0.554316
# 5    0.784892  0.760276  0.525272  0.418736  0.835230
# ..        ...       ...       ...       ...       ...
# 438  0.807617  0.081209  0.139690  0.825553  0.094354
# 439  0.985746  0.102980  0.671839  0.336475  0.362165
# 441  0.612678  0.704572  0.355077  0.002490  0.082120
# 442  0.534451  0.404527  0.873619  0.575251  0.915457
# 443   0.20947  0.406620  0.171258  0.115146  0.074322
#
# [442 rows x 5 columns]

# %%
new_df.reset_index(drop=True, inplace=True)

# %%
new_df
# Out:
#             A         B         C         D         E
# 0         0.5  0.389168  0.052477  6.000000  0.407235
# 1    0.060224  0.987430  0.005725  0.153605  0.256132
# 2     0.72861  0.238399  0.018725  0.408156  0.815878
# 3    0.917867  0.467754  0.046411  0.870903  0.554316
# 4    0.784892  0.760276  0.525272  0.418736  0.835230
# ..        ...       ...       ...       ...       ...
# 437  0.807617  0.081209  0.139690  0.825553  0.094354
# 438  0.985746  0.102980  0.671839  0.336475  0.362165
# 439  0.612678  0.704572  0.355077  0.002490  0.082120
# 440  0.534451  0.404527  0.873619  0.575251  0.915457
# 441   0.20947  0.406620  0.171258  0.115146  0.074322
#
# [442 rows x 5 columns]

# %%
new_data = {
    'A' : [None, None, 4, 6, 7, 9],
    'B' : [0, 3, 5, 7, None, 8],
    'C' : [5, None, 4, 56, 6, 90],
    'D' : [239, 234, None, 0, 0, 23]
    
}
new_data = pd.DataFrame(new_data)

# %%
new_data
# Out:
#      A    B     C      D
# 0  NaN  0.0   5.0  239.0
# 1  NaN  3.0   NaN  234.0
# 2  4.0  5.0   4.0    NaN
# 3  6.0  7.0  56.0    0.0
# 4  7.0  NaN   6.0    0.0
# 5  9.0  8.0  90.0   23.0

# %%
new_data.dropna()
# Out:
#      A    B     C     D
# 3  6.0  7.0  56.0   0.0
# 5  9.0  8.0  90.0  23.0

# %%
new_data.columns = ["K", "L", "M", "N"]

# %%
new_data
# Out:
#      K    L     M      N
# 0  NaN  0.0   5.0  239.0
# 1  NaN  3.0   NaN  234.0
# 2  4.0  5.0   4.0    NaN
# 3  6.0  7.0  56.0    0.0
# 4  7.0  NaN   6.0    0.0
# 5  9.0  8.0  90.0   23.0

# %%
new_data.rename(index={_:__ for _, __ in enumerate("GAUTAM")})
# Out:
#      K    L     M      N
# G  NaN  0.0   5.0  239.0
# A  NaN  3.0   NaN  234.0
# U  4.0  5.0   4.0    NaN
# T  6.0  7.0  56.0    0.0
# A  7.0  NaN   6.0    0.0
# M  9.0  8.0  90.0   23.0

# %%
new_data.drop_duplicates(subset=new_data.columns)
# Out:
#      K    L     M      N
# 0  NaN  0.0   5.0  239.0
# 1  NaN  3.0   NaN  234.0
# 2  4.0  5.0   4.0    NaN
# 3  6.0  7.0  56.0    0.0
# 4  7.0  NaN   6.0    0.0
# 5  9.0  8.0  90.0   23.0

# %%
new_data.isnull()
new_data["K"].isnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: K, dtype: bool

# %%
new_data.drop([0, 5], axis=0)
# Out:
#      K    L     M      N
# 1  NaN  3.0   NaN  234.0
# 2  4.0  5.0   4.0    NaN
# 3  6.0  7.0  56.0    0.0
# 4  7.0  NaN   6.0    0.0

# %%
new_df["B"] = 0
new_df["B"] == 0
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 437    True
# 438    True
# 439    True
# 440    True
# 441    True
# Name: B, Length: 442, dtype: bool

# %%
new_df.loc[:, ["B"]] = None
new_df.loc[:, ["B"]].isnull().head()
# Out:
#       B
# 0  True
# 1  True
# 2  True
# 3  True
# 4  True

# %%
new_df.loc[:, ["C"]].describe()
# Out:
#                 C
# count  442.000000
# mean     0.489151
# std      0.299504
# min      0.001943
# 25%      0.224216
# 50%      0.486578
# 75%      0.751956
# max      0.999605

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Alfred'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})

# %%
df.dropna()
df.dropna(how="any", axis=1)
# Out:
#      name
# 0  Alfred
# 1  Batman
# 2  Alfred

# %%
df.drop_duplicates(subset=["name"], keep=False)
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.shape
new_data.shape
new_df.shape
# Out:
# (442, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes

# %%
df.loc[:, ["name"]].value_counts()
# Out:
# name
# Alfred    2
# Batman    1
# dtype: int64

# %%
df.loc[[0, 1], ["name", "toy"]].value_counts(dropna=False)
# Out:
# name    toy
# Alfred  NaN          1
# Batman  Batmobile    1
# dtype: int64

# %%
df.notnull()
# Out:
#    name    toy   born
# 0  True  False  False
# 1  True   True   True
# 2  True   True  False

# %%
df.isnull()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %% [markdown]
# # I/O in Exel Sheets with Pandas

# %%
contacts = pd.read_excel("contacts.xlsx", sheet_name="contacts")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2588/2165040872.py in <module>
# ----> 1 contacts = pd.read_excel("contacts.xlsx", sheet_name="contact1")
#
# c:\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\python39\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     370
#     371     try:
# --> 372         data = io.parse(
# ...

# %%
contacts.fillna(value={"E-mail address" : "Not in Server", "Phone Number" : "Out of Contacts"}, inplace = True)

# %%
contacts.iloc[:, [2]] == "Out of Contacts"

# %%
contacts.iloc[0, 2] = 234235423
contacts

# %%
contacts2 = pd.read_excel("contacts.xlsx", sheet_name="contacts2")

# %%
new_data = {"Name" : "Abhinav Choudhary", "E-mail address" : "abhinavchaudhary351@gmail.com", "Phone Number" : "+91 8092347234"}
contacts2 = contacts2.append(new_data, ignore_index=True)

# %%
contacts2

# %%
# contacts2.to_excel("contacts.xlsx", sheet_name='contacts2')

# %%
with pd.ExcelWriter('contacts.xlsx') as writer:  
    contacts.to_excel(writer, sheet_name='contact1')
    contacts2.to_excel(writer, sheet_name='contact2')

# %%
# samjh rahe ho
